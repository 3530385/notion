# %%
import plotly.express as px

fig =px.scatter(x=range(10), y=range(10))
fig.write_html("file.html")

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv('tablenow.csv')

# %%
from datetime import timedelta
def get_profits(days,full_dates,profits):
    days=sorted(days)
    days+=[date.today()]
    full_profits=[]
    i=0
    for day in full_dates:
        if days[i+1]<=day and i!=len(profits)-1:
            i+=1
            full_profits.append(profits[i])
            continue
        full_profits.append(profits[i])
    return full_profits


def get_days(days):
    full_dates=[]
    start=days[0]
    full_dates.append(start)
    stop=date.today()
    delta=stop-start
    for _ in range(delta.days):
        start+=timedelta(days=1)
        full_dates.append(start)
    return full_dates


dfn=df.loc[df['Done']=='Yes']
dfn['Time done in dt']=dfn['Time done'].apply(not_to_dt)
days=dfn['Time done in dt'].unique()
profits=[0]
for day in days:
    profits+=[profits[-1]+dfn.loc[dfn['Time done in dt']==day,'Cost'].sum()]
profits=profits[1:]
full_dates=get_days(days)
full_profits=get_profits(days,full_dates,profits)
fig=px.area(x=full_dates, y=full_profits,markers=True)
fig.update_layout( 
    xaxis=dict(
        showline=True,
        showgrid=True,
        showticklabels=True,
        linecolor='rgb(204, 204, 204)',
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        )),
    yaxis=dict(
        showline=True,
        showgrid=True,
        showticklabels=True,
        linecolor='rgb(204, 204, 204)',
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        )),
    xaxis_title="",
    yaxis_title="")
fig.write_html("index.html")

# %%
from datetime import date
def not_to_dt(notion_time):
    months=['January', 'February', 'March',
            'April', 'May', 'June', 'July',
            'August', 'September', 'October',
            'November', 'December']
    timesplit=notion_time.replace(',', '').split()
    month=months.index(timesplit[0])+1
    day=int(timesplit[1])
    year=int(timesplit[2])
    return date(year, month, day)
not_to_dt('November 23, 2021 9:59 PM')
df['Time done'].apply(not_to_dt)
# Out:
# 0     2021-11-23
# 1     2021-11-23
# 2     2021-11-23
# 3     2021-11-23
# 4     2021-11-23
#          ...
# 95    2022-07-10
# 96    2022-07-10
# 97    2022-07-10
# 98    2022-07-12
# 99    2022-07-15
# Name: Time done, Length: 100, dtype: object

# %%
profits=[0]
for day in dfn['Time done'].unique():
    profits+=[profits[-1]+dfn.loc[dfn['Time done']==day,'Cost'].sum()]
profits=profits[1:]
# Out:
# [4927.139999999999,
#  5200.869999999999,
#  5474.5999999999985,
#  5748.329999999998,
#  6022.059999999998,
#  6295.789999999997,
#  6569.519999999997,
#  6843.249999999996]

# %%
dfn.loc[dfn['Time done']==day,'Cost'].sum()

# %%
[dfn.loc[df["Order"] <= v, "Cost"].sum() for v in dfn["Order"]]
# Out:
# [273.73,
#  547.46,
#  821.19,
#  1094.92,
#  1368.65,
#  1642.38,
#  1916.1100000000001,
#  2189.84,
#  2463.57,
#  2737.3,
#  3011.03,
#  3284.76,
#  3558.4900000000002,
#  3832.2200000000003,
#  3832.2200000000003,
#  4105.950000000001,
#  4379.68,
#  4653.41,
#  4927.139999999999,
#  5200.869999999999,
#  5474.5999999999985,
#  5748.329999999998,
#  6022.059999999998,
#  6295.790000000001,
#  6569.52,
#  6843.25,
#  6843.25]

# %%
dfn.sort_values()
# Out:
#                  Name    Cost Done Process     Time   Efficiency  Late  \
# 0         §1 Вопрос 1  273.73  Yes      No  0:43:05   381.210058    23
# 16  October 31, 2021  November 23, 2021 9:59 PM     16        2881.0
# 17  October 31, 2021  November 23, 2021 9:59 PM     17        1061.0
# 18  October 31, 2021  November 23, 2021 9:59 PM     18        1190.0
# 19  October 31, 2021  November 23, 2021 9:48 PM     19        5609.0
# 20  October 31, 2021  November 23, 2021 9:49 PM     20        2804.0
# 21  October 31, 2021   January 23, 2022 1:57 PM     21        2396.0
# 22  October 31, 2021   January 23, 2022 2:20 PM     22        1299.0
# 23  October 31, 2021   January 23, 2022 3:00 PM     23        1846.0
# 24  October 31, 2021   January 25, 2022 9:47 PM     24        3845.0
# 25  October 31, 2021   January 27, 2022 4:44 PM     25        2804.0
# 26  October 31, 2021   January 27, 2022 7:42 PM     26        3375.0

# %%
dfn['Time done'].unique()
# Out:
# array(['November 23, 2021 9:59 PM', 'January 29, 2022 6:38 PM',
#        'November 23, 2021 9:48 PM', 'November 23, 2021 9:49 PM',
#        'January 23, 2022 1:57 PM', 'January 23, 2022 2:20 PM',
#        'January 23, 2022 3:00 PM', 'January 25, 2022 9:47 PM',
#        'January 27, 2022 4:44 PM', 'January 27, 2022 7:42 PM'],
#       dtype=object)

# %%
[dfn.loc[(dfn['Time done']==time) & (dfn['Done']=='Yes'), 'Cost'] for time in dfn['Time done'].unique()]
#[dfn.loc[df["Order"] <= v, "Cost"].sum() for v in dfn["Order"]]
# Out:
# [0     273.73
#  1     273.73
#  2     273.73
#  3     273.73
#  4     273.73
#  5     273.73
#  6     273.73
#  7     273.73
#  8     273.73
#  9     273.73
#  10    273.73
#  11    273.73
#  12    273.73
#  13    273.73
#  15    273.73
#  16    273.73
#  17    273.73
#  18    273.73
#  Name: Cost, dtype: float64,
#  Series([], Name: Cost, dtype: float64),
#  19    273.73
#  Name: Cost, dtype: float64,
#  20    273.73
#  Name: Cost, dtype: float64,
#  21    273.73
#  Name: Cost, dtype: float64,
#  22    273.73
#  Name: Cost, dtype: float64,
#  23    273.73
#  Name: Cost, dtype: float64,
#  24    273.73
#  Name: Cost, dtype: float64,
#  25    273.73
#  Name: Cost, dtype: float64,
#  Series([], Name: Cost, dtype: float64)]

# %%
dfn['total_sum']=[dfn.loc[df["Order"] <= v, "Cost"].sum() for v in dfn["Order"]]
profit=[max(dfn.loc[dfn['Time done']==time, 'total_sum']) for time in dfn['Time done'].unique()]
# Out:
# C:\Users\B7E3~1\AppData\Local\Temp/ipykernel_12588/3324754696.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [4927.139999999999,
#  3832.2200000000003,
#  5200.869999999999,
#  5474.5999999999985,
#  5748.329999999998,
#  6022.059999999998,
#  6295.790000000001,
#  6569.52,
#  6843.25,
#  6843.25]

# %%
dfn['Time done in dt']=dfn['Time done'].apply(not_to_dt)
dfn=dfn.sort_values('Time done in dt')

for index, row in dfn.iterrows():
    print(index,row['Time done'], row['Time done'])
# Out:
# 0 November 23, 2021 9:59 PM
# 1 November 23, 2021 9:59 PM
# 2 November 23, 2021 9:59 PM
# 3 November 23, 2021 9:59 PM
# 4 November 23, 2021 9:59 PM
# 5 November 23, 2021 9:59 PM
# 6 November 23, 2021 9:59 PM
# 7 November 23, 2021 9:59 PM
# 20  October 31, 2021  November 23, 2021 9:49 PM     20        2804.0
# 19  October 31, 2021  November 23, 2021 9:48 PM     19        5609.0
# 18  October 31, 2021  November 23, 2021 9:59 PM     18        1190.0
# 17  October 31, 2021  November 23, 2021 9:59 PM     17        1061.0
# 16  October 31, 2021  November 23, 2021 9:59 PM     16        2881.0
# 15  October 31, 2021  November 23, 2021 9:59 PM     15        1365.0
# 12  October 31, 2021  November 23, 2021 9:59 PM     12        1179.0
# 11  October 31, 2021  November 23, 2021 9:59 PM     11         951.0
# 10  October 31, 2021  November 23, 2021 9:59 PM     10        5217.0
# 13  October 31, 2021  November 23, 2021 9:59 PM     13        1245.0
# 8   October 31, 2021  November 23, 2021 9:59 PM      8        1430.0
# 7   October 31, 2021  November 23, 2021 9:59 PM      7        1398.0
# 6   October 31, 2021  November 23, 2021 9:59 PM      6        1036.0
# 5   October 31, 2021  November 23, 2021 9:59 PM      5        1960.0
# 4   October 31, 2021  November 23, 2021 9:59 PM      4        1595.0
# 3   October 31, 2021  November 23, 2021 9:59 PM      3        1320.0
# 2   October 31, 2021  November 23, 2021 9:59 PM      2         901.0
# 1   October 31, 2021  November 23, 2021 9:59 PM      1        1261.0
# 9   October 31, 2021  November 23, 2021 9:59 PM      9        1016.0
# 21  October 31, 2021   January 23, 2022 1:57 PM     21        2396.0
# 22  October 31, 2021   January 23, 2022 2:20 PM     22        1299.0
# 23  October 31, 2021   January 23, 2022 3:00 PM     23        1846.0
# 24  October 31, 2021   January 25, 2022 9:47 PM     24        3845.0
# 25  October 31, 2021   January 27, 2022 4:44 PM     25        2804.0
# 26  October 31, 2021   January 27, 2022 7:42 PM     26        3375.0
# 14  October 31, 2021   January 29, 2022 6:38 PM     14        1684.0
#
#     total_sum Time done in dt
# 0      273.73      2021-11-23
# 20    5474.60      2021-11-23
# 19    5200.87      2021-11-23
# 18    4927.14      2021-11-23
# 17    4653.41      2021-11-23
# 16    4379.68      2021-11-23
# 15    4105.95      2021-11-23
# 12    3558.49      2021-11-23
# 11    3284.76      2021-11-23
# 10    3011.03      2021-11-23
# 13    3832.22      2021-11-23
# 8     2463.57      2021-11-23
# 7     2189.84      2021-11-23
# 6     1916.11      2021-11-23
# 5     1642.38      2021-11-23
# 4     1368.65      2021-11-23
# 3     1094.92      2021-11-23
# 2      821.19      2021-11-23
# 1      547.46      2021-11-23
# 9     2737.30      2021-11-23
# 21    5748.33      2022-01-23
# 22    6022.06      2022-01-23
# 23    6295.79      2022-01-23
# 24    6569.52      2022-01-25
# 25    6843.25      2022-01-27
# 26    6843.25      2022-01-27
# 14    3832.22      2022-01-29

# %%
# Run this app with `python app.py` and
# visit http://127.0.0.1:8050/ in your web browser.

import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
import pandas as pd

app = dash.Dash(__name__)

colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

# assume you have a "long-form" data frame
# see https://plotly.com/python/px-arguments/ for more options
df = pd.DataFrame({
    "Fruit": ["Apples", "Oranges", "Bananas", "Apples", "Oranges", "Bananas"],
    "Amount": [4, 1, 2, 2, 4, 5],
    "City": ["SF", "SF", "SF", "Montreal", "Montreal", "Montreal"]
})

fig = px.bar(df, x="Fruit", y="Amount", color="City", barmode="group")

fig.update_layout(
    plot_bgcolor=colors['background'],
    paper_bgcolor=colors['background'],
    font_color=colors['text']
)

app.layout = html.Div(style={'backgroundColor': colors['background']}, children=[
    html.H1(
        children='Hello Dash',
        style={
            'textAlign': 'center',
            'color': colors['text']
        }
    ),

    html.Div(children='Dash: A web application framework for your data.', style={
        'textAlign': 'center',
        'color': colors['text']
    }),

    dcc.Graph(
        id='example-graph-2',
        figure=fig
    )
])

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# C:\Users\B7E3~1\AppData\Local\Temp/ipykernel_12152/2404253914.py:5: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\B7E3~1\AppData\Local\Temp/ipykernel_12152/2404253914.py:6: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Python39\lib\site-packages\IPython\core\interactiveshell.py:3465: UserWarning:
#
# To exit: use 'exit', 'quit', or Ctrl-D.

# %% [markdown]
# # Преобразуем данные из API в Pandas

# %%
p=Parser()
p.get_pages()
# Out:
# [{'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 87},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§12 Упражнение 12.1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§12 Упражнение 12.1',
#      'href': None}]},
#   'id': '00cced85-5653-4815-af76-720a569aaf44'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 82},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§12 Вопрос 1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§12 Вопрос 1',
#      'href': None}]},
#   'id': '03d9f39c-c4c9-4280-95b8-3c63f38bd6dd'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 71},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§11 Вопрос 1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§11 Вопрос 1',
#      'href': None}]},
#   'id': '04d78b90-7d55-4d0c-a48c-359dc7037d74'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 50},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§8 Вопрос 2', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§8 Вопрос 2',
#      'href': None}]},
#   'id': '04da90e8-0c56-40ee-b983-f018c0927d2c'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 43},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§6 Упражнение 6.5', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§6 Упражнение 6.5',
#      'href': None}]},
#   'id': '07e05a8f-6e11-4fdd-a830-f650608cde85'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 54},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§8 Упражнение 8.1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§8 Упражнение 8.1',
#      'href': None}]},
#   'id': '0ad098c5-0d5c-40f6-b312-bbdb3495ba6d'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 39},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§6 Упражнение 6.1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§6 Упражнение 6.1',
#      'href': None}]},
#   'id': '0dca7d75-3d66-4aee-bb5f-031361dc83ae'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 40},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§6 Упражнение 6.2', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§6 Упражнение 6.2',
#      'href': None}]},
#   'id': '0de3f6a4-bce3-44d7-ac7e-fe42af4238b4'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 23},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': True},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 533.817984832069}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 273.73}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2022-01-23T12:00:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 84}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '0:30:46', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '0:30:46',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': 1846},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§4 Вопрос 3', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§4 Вопрос 3',
#      'href': None}]},
#   'id': '10e6804b-9e7a-4b93-a75b-b4e38357419f'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 97},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§13 Упражнение 13.2', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§13 Упражнение 13.2',
#      'href': None}]},
#   'id': '16ca6871-6b09-426a-87a4-cd99f9481915'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 21},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': True},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 411.280467445743}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 273.73}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2022-01-23T10:57:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 84}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '0:39:56', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '0:39:56',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': 2396},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§4 Вопрос 1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§4 Вопрос 1',
#      'href': None}]},
#   'id': '1b438bc7-8ec0-4957-be54-f7376d3bc61d'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 75},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§11 Вопрос 5', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§11 Вопрос 5',
#      'href': None}]},
#   'id': '1b73d8ed-32a9-4458-a796-6089faf13eaa'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 62},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§9 Упражнение 9.3', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§9 Упражнение 9.3',
#      'href': None}]},
#   'id': '1bc3225b-666b-4cc3-9b84-702fc9491118'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 86},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§12 Вопрос 5', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§12 Вопрос 5',
#      'href': None}]},
#   'id': '1f2f8251-8e99-4995-84ff-1457ac185da6'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 83},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§12 Вопрос 2', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§12 Вопрос 2',
#      'href': None}]},
#   'id': '21d4b58a-bb2a-4d10-b289-2bf61da57052'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 42},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§6 Упражнение 6.4', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§6 Упражнение 6.4',
#      'href': None}]},
#   'id': '25b0ba97-45b7-4297-b2f0-84faca182dd1'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 29},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§5 Вопрос 3', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§5 Вопрос 3',
#      'href': None}]},
#   'id': '2a9d3e9b-b823-45f2-bb18-4ecbd4649eae'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 81},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§11 Упражнение 11.6', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§11 Упражнение 11.6',
#      'href': None}]},
#   'id': '2bbdfba8-98cd-4f83-bbde-6f1f91ada318'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 16},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': True},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 342.043734814301}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 273.73}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-23T18:59:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 23}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '0:48:01', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '0:48:01',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': 2881},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§3 Вопрос 1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§3 Вопрос 1',
#      'href': None}]},
#   'id': '2d97e572-9305-4e38-831a-f7b5a92257fd'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 41},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§6 Упражнение 6.3', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§6 Упражнение 6.3',
#      'href': None}]},
#   'id': '32fd84b5-ab66-4a62-8b3b-7a08c281d508'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 17},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': True},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 928.772855796419}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 273.73}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-23T18:59:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 23}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '0:17:41', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '0:17:41',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': 1061},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§3 Вопрос 2', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§3 Вопрос 2',
#      'href': None}]},
#   'id': '3510fd67-2050-4353-9281-fef0bef78c6a'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 48},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§7 Упражнение 7.3', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§7 Упражнение 7.3',
#      'href': None}]},
#   'id': '37b5b848-7c93-413b-8175-8a5bfdc0c294'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 32},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§5 Вопрос 6', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§5 Вопрос 6',
#      'href': None}]},
#   'id': '39bdc7a0-ee59-42e2-a7a5-8f4611d4edc3'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 56},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§8 Упражнение 8.3', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§8 Упражнение 8.3',
#      'href': None}]},
#   'id': '40acbe7f-9897-4d75-85cf-face22a4842a'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 61},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§9 Упражнение 9.2', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§9 Упражнение 9.2',
#      'href': None}]},
#   'id': '4297e69f-b4a7-4d19-85c4-29dbf82b78f9'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 12},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': True},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 835.81679389313}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 273.73}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-23T18:59:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 23}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '0:19:39', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '0:19:39',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': 1179},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§2 Вопрос 2', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§2 Вопрос 2',
#      'href': None}]},
#   'id': '48a6e8ee-f91f-4cdb-8872-a6ed28e8fa94'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 47},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§7 Упражнение 7.2', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§7 Упражнение 7.2',
#      'href': None}]},
#   'id': '496825d2-3087-499a-b918-929e16b73682'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 57},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§9 Вопрос 1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§9 Вопрос 1',
#      'href': None}]},
#   'id': '4bb19bb2-d355-40d9-8bdc-e2cd377d1e13'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 93},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§13 Вопрос 4', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§13 Вопрос 4',
#      'href': None}]},
#   'id': '4f99536b-9c3f-452e-8151-f5dea53713db'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 44},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§7 Вопрос 1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§7 Вопрос 1',
#      'href': None}]},
#   'id': '520ef02c-fec7-4313-a6e7-70daaefc939c'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 2},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': True},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 1093.704772475028}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 273.73}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-23T18:59:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 23}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '0:15:01', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '0:15:01',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': 901},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§1 Вопрос 3', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§1 Вопрос 3',
#      'href': None}]},
#   'id': '554d9620-f70e-4f1e-8e80-b65583a33a18'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 66},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
# ...
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§8 Вопрос 5', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§8 Вопрос 5',
#      'href': None}]},
#   'id': 'e60333b0-b1f6-4c28-ac44-c39b02518a01'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 28},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§5 Вопрос 2', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§5 Вопрос 2',
#      'href': None}]},
#   'id': 'e6f952b8-dfb6-449d-87ce-51eb2325293e'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 8},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': True},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 689.11048951049}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 273.73}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-23T18:59:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 23}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '0:23:50', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '0:23:50',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': 1430},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§1 Упражнение 1.3', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§1 Упражнение 1.3',
#      'href': None}]},
#   'id': 'e977e793-fd62-4ee9-a74f-64d830af284b'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 79},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§11 Упражнение 11.4', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§11 Упражнение 11.4',
#      'href': None}]},
#   'id': 'ea8b71a9-5937-4018-b24e-629bb8c61055'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 89},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§12 Упражнение 12.3', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§12 Упражнение 12.3',
#      'href': None}]},
#   'id': 'ed7ff8e0-3477-4a3e-b741-6ed613eb18b0'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 30},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§5 Вопрос 4', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§5 Вопрос 4',
#      'href': None}]},
#   'id': 'ee090a31-2ed5-4cc4-9ecc-04304970fd64'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 0},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': True},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 381.210058027079}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 273.73}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-23T18:59:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 23}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '0:43:05', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '0:43:05',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': 2585},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§1 Вопрос 1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§1 Вопрос 1',
#      'href': None}]},
#   'id': 'efb228a2-1865-4890-a4be-9e043c1135d4'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 69},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§10 Вопрос 5', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§10 Вопрос 5',
#      'href': None}]},
#   'id': 'f893d8eb-ecaf-49da-a7c8-ae51f118a53c'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 11},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': True},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 1036.201892744479}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 273.73}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-23T18:59:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 23}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '0:15:51', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '0:15:51',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': 951},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§2 Вопрос 1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§2 Вопрос 1',
#      'href': None}]},
#   'id': 'f9f9fbbb-fdca-4d26-8421-acc04ae4d3a4'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 80},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': False},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 0}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-03T13:51:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 3}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '1', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '1',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': None},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§11 Упражнение 11.5', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§11 Упражнение 11.5',
#      'href': None}]},
#   'id': 'fb97245b-150a-4942-8e8b-bfdaa1ed81eb'},
#  {'Order': {'id': '%3BTU%5B', 'type': 'number', 'number': 13},
#   'Done': {'id': '%40qq%3C', 'type': 'checkbox', 'checkbox': True},
#   'Process': {'id': 'D%5BC%5C', 'type': 'checkbox', 'checkbox': False},
#   'Efficiency': {'id': 'F%5CN%3B',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 791.50843373494}},
#   'Cost': {'id': 'Jfa_',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 273.73}},
#   'Time done': {'id': 'KXlU',
#    'type': 'last_edited_time',
#    'last_edited_time': '2021-11-23T18:59:00.000Z'},
#   'Late': {'id': 'OIKj',
#    'type': 'formula',
#    'formula': {'type': 'number', 'number': 23}},
#   'Time': {'id': 'vrBx',
#    'type': 'rich_text',
#    'rich_text': [{'type': 'text',
#      'text': {'content': '0:20:45', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '0:20:45',
#      'href': None}]},
#   'Due': {'id': 'ytlS',
#    'type': 'date',
#    'date': {'start': '2021-10-31', 'end': None, 'time_zone': None}},
#   'Time_seconds': {'id': '~%3CpA', 'type': 'number', 'number': 1245},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': '§2 Вопрос 3', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
#      'plain_text': '§2 Вопрос 3',
#      'href': None}]},
#   'id': 'ff16454c-24ee-4ae5-bdf9-baf611095655'}]

# %%
sorted(days), profits
# Out:
# ([datetime.date(2021, 11, 23),
#   datetime.date(2022, 1, 23),
#   datetime.date(2022, 1, 25),
#   datetime.date(2022, 1, 27),
#   datetime.date(2022, 1, 29),
#   datetime.date(2022, 2, 1),
#   datetime.date(2022, 2, 6),
#   datetime.date(2022, 2, 7),
#   datetime.date(2022, 2, 8)],
#  [5474.5999999999985,
#   5748.329999999998,
#   6569.519999999999,
#   6843.249999999998,
#   7116.979999999998,
#   8485.629999999997,
#   8759.359999999997,
#   9033.089999999997,
#   9306.819999999996])

# %%
def get_days(days):
    full_dates=[]
    start=days[0]
    full_dates.append(start)
    stop=date.today()
    delta=stop-start
    for _ in range(delta.days):
        start+=timedelta(days=1)
        full_dates.append(start)
    return full_dates
full_dates=get_days(days)
full_dates
# Out:
# [datetime.date(2021, 11, 23),
#  datetime.date(2021, 11, 24),
#  datetime.date(2021, 11, 25),
#  datetime.date(2021, 11, 26),
#  datetime.date(2021, 11, 27),
#  datetime.date(2021, 11, 28),
#  datetime.date(2021, 11, 29),
#  datetime.date(2021, 11, 30),
#  datetime.date(2021, 12, 1),
#  datetime.date(2021, 12, 2),
#  datetime.date(2021, 12, 3),
#  datetime.date(2021, 12, 4),
#  datetime.date(2021, 12, 5),
#  datetime.date(2021, 12, 6),
#  datetime.date(2021, 12, 7),
#  datetime.date(2021, 12, 8),
#  datetime.date(2021, 12, 9),
#  datetime.date(2021, 12, 10),
#  datetime.date(2021, 12, 11),
#  datetime.date(2021, 12, 12),
#  datetime.date(2021, 12, 13),
#  datetime.date(2021, 12, 14),
#  datetime.date(2021, 12, 15),
#  datetime.date(2021, 12, 16),
#  datetime.date(2021, 12, 17),
#  datetime.date(2021, 12, 18),
#  datetime.date(2021, 12, 19),
#  datetime.date(2021, 12, 20),
#  datetime.date(2021, 12, 21),
#  datetime.date(2021, 12, 22),
#  datetime.date(2021, 12, 23),
#  datetime.date(2021, 12, 24),
#  datetime.date(2021, 12, 25),
#  datetime.date(2021, 12, 26),
#  datetime.date(2021, 12, 27),
#  datetime.date(2021, 12, 28),
#  datetime.date(2021, 12, 29),
#  datetime.date(2021, 12, 30),
#  datetime.date(2021, 12, 31),
#  datetime.date(2022, 1, 1),
#  datetime.date(2022, 1, 2),
#  datetime.date(2022, 1, 3),
#  datetime.date(2022, 1, 4),
#  datetime.date(2022, 1, 5),
#  datetime.date(2022, 1, 6),
#  datetime.date(2022, 1, 7),
#  datetime.date(2022, 1, 8),
#  datetime.date(2022, 1, 9),
#  datetime.date(2022, 1, 10),
#  datetime.date(2022, 1, 11),
#  datetime.date(2022, 1, 12),
#  datetime.date(2022, 1, 13),
#  datetime.date(2022, 1, 14),
#  datetime.date(2022, 1, 15),
#  datetime.date(2022, 1, 16),
#  datetime.date(2022, 1, 17),
#  datetime.date(2022, 1, 18),
#  datetime.date(2022, 1, 19),
#  datetime.date(2022, 1, 20),
#  datetime.date(2022, 1, 21),
#  datetime.date(2022, 1, 22),
#  datetime.date(2022, 1, 23),
#  datetime.date(2022, 1, 24),
#  datetime.date(2022, 1, 25),
#  datetime.date(2022, 1, 26),
#  datetime.date(2022, 1, 27),
#  datetime.date(2022, 1, 28),
#  datetime.date(2022, 1, 29),
#  datetime.date(2022, 1, 30),
#  datetime.date(2022, 1, 31),
#  datetime.date(2022, 2, 1),
#  datetime.date(2022, 2, 2),
#  datetime.date(2022, 2, 3),
#  datetime.date(2022, 2, 4),
#  datetime.date(2022, 2, 5),
#  datetime.date(2022, 2, 6),
#  datetime.date(2022, 2, 7),
#  datetime.date(2022, 2, 8),
#  datetime.date(2022, 2, 9),
#  datetime.date(2022, 2, 10),
#  datetime.date(2022, 2, 11),
#  datetime.date(2022, 2, 12),
#  datetime.date(2022, 2, 13),
#  datetime.date(2022, 2, 14),
#  datetime.date(2022, 2, 15),
#  datetime.date(2022, 2, 16)]

# %%
def get_profits(days,full_dates,profits):
    days=sorted(days)
    days+=[date.today()]
    print(days)
    full_profits=[]
    i=0
    for day in full_dates:
        
        print(day,days[i],day>=days[i], i)
        if days[i+1]<=day and i!=len(profits)-1:
            i+=1
            full_profits.append(profits[i])
            continue
        full_profits.append(profits[i])
    return full_profits
get_profits(days,full_dates,profits)
# Out:
# [datetime.date(2021, 11, 23), datetime.date(2022, 1, 23), datetime.date(2022, 1, 25), datetime.date(2022, 1, 27), datetime.date(2022, 1, 29), datetime.date(2022, 2, 1), datetime.date(2022, 2, 6), datetime.date(2022, 2, 7), datetime.date(2022, 2, 8), datetime.date(2022, 2, 16)]
# 2021-11-23 2021-11-23 True 0
# 2021-11-24 2021-11-23 True 0
# 2021-11-25 2021-11-23 True 0
# 2021-11-26 2021-11-23 True 0
# 2021-11-27 2021-11-23 True 0
# 2021-11-28 2021-11-23 True 0
# 2021-11-29 2021-11-23 True 0
# 2021-11-30 2021-11-23 True 0
# 2021-12-01 2021-11-23 True 0
# 2021-12-02 2021-11-23 True 0
# 2021-12-03 2021-11-23 True 0
# 2021-12-04 2021-11-23 True 0
# 2021-12-05 2021-11-23 True 0
# 2021-12-06 2021-11-23 True 0
# 2021-12-07 2021-11-23 True 0
# 2021-12-08 2021-11-23 True 0
# 2021-12-09 2021-11-23 True 0
# 2021-12-10 2021-11-23 True 0
# 2021-12-11 2021-11-23 True 0
# 2021-12-12 2021-11-23 True 0
